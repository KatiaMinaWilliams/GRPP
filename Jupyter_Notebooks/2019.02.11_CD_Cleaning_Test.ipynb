# %%
import pandas as pd
import re
import numpy as np

# %%
test = pd.read_csv("2019.02.20 Corporate SDG Commitments.csv")

# %%
#Coding NaN as SDG 0
test.iloc[:,1:2] = test.iloc[:,1:2].fillna(0)

# %%
############################
## Wide to Narrow Helpers ##
############################

#splitInt takes a string s of comma deliniated items and returns an array of those items cast as integers. 
#Ignores whitespace.
def splitInt(s):
    s = str(s)
    return np.array(list(map(int, re.split(r" ?, ?", s))))

#splitStr takes a string s of comma deliniated items and returns an array of those items cast as strings. 
#Ignores whitespace.

def splitStr(s):
    s = str(s)
    return np.array(list(map(str, re.split(r" *[,;] *", s))))

#repRow takes a series ser that represents a dataframe row, a column index col, and a splitter function f.
#Reurns that row repeated, but with column col replaced with one of the split elements from applying f to col.
def repRow(ser, col, f):
    splitted = f(ser[col])
    serDf = pd.DataFrame(ser).transpose()
    retDf = pd.DataFrame(pd.np.repeat(serDf.values, len(splitted), axis=0), columns = serDf.columns)
    retDf.iloc[:,col] = splitted
    return retDf

# %%
cleanTest = pd.DataFrame([])
testLen = len(test.iloc[:, 0])
for row in range(testLen):
    cleanTest = cleanTest.append(repRow(test.iloc[row], 1, splitInt))
cleanTest = cleanTest.reset_index().iloc[:, 1:11]
cleanTest
# Out:
#                   Corporation  SDG(s)   \
# 0                       Adobe        4
# 1                       Adobe        5
# 2                       Adobe        8
# 3                       Adobe       12
# 4                       Adobe       13
# 5                         ADP        1
# 6                         ADP        2
# 7                         ADP        3
# 8                         ADP        4
# 9                         ADP        5
# 10                        ADP        8
# 11                        ADP       10
# 12                        ADP       13
# 13             Alpha Software        0
# 14                      Altum        2
# 15        Amazon Web Services        7
# 16        Amazon Web Services       13
# 17        Amazon Web Services       14
# 18        Amazon Web Services       15
# 19                     Arreva        0
# 20                      Asana       10
# 21   Atlas Business Solutions        0
# 22                   Autodesk        7
# 23                   Autodesk       13
# 24                   Autodesk       15
# 25                   Autodesk        4
# 26                   Autodesk       11
# 27                   Autodesk       19
# 28                   Autodesk        7
# 29                   Autodesk        9
# ..                        ...      ...
# 279           Western Digital        2
# 280           Western Digital        3
# 281           Western Digital        4
# 282           Western Digital        8
# 283           Western Digital       11
# 284           Western Digital       13
# 285           Western Digital       16
# 286           Western Digital        3
# 287           Western Digital        8
# 288           Western Digital       12
# 289           Western Digital       16
# 290           Western Digital       16
# 291           Western Digital       12
# 292           Western Digital       17
# 293           Western Digital       17
# 294           Western Digital       12
# 295           Western Digital       13
# 296                     Zoner        0
# 297                      Zoom        3
# 298                      Zoom        8
# 299                      Zoom        4
# 300                      Zoom        4
# 301                      Zoom        4
# 302                      Zoom        8
# 303                      Zoom        3
# 304                      Zoom        4
# 305                      Zoom       11
# 306                      Zoom        1
# 307                      Zoom        4
# 308                      Zoom        5
#
#                                            Source Name  \
# 0    Adobe Alignment to UN Sustainable Development ...
# 1    Adobe Alignment to UN Sustainable Development ...
# 2    Adobe Alignment to UN Sustainable Development ...
# 3    Adobe Alignment to UN Sustainable Development ...
# 4    Adobe Alignment to UN Sustainable Development ...
# 5               Corporate Social Responsibility Report
# 6               Corporate Social Responsibility Report
# 7               Corporate Social Responsibility Report
# 8               Corporate Social Responsibility Report
# 9               Corporate Social Responsibility Report
# 10              Corporate Social Responsibility Report
# 11              Corporate Social Responsibility Report
# 12              Corporate Social Responsibility Report
# 13                                                 NaN
# 14                                           Community
# 15                                AWS & Sustainability
# 16                                AWS & Sustainability
# 17                                AWS & Sustainability
# 18                                AWS & Sustainability
# 19                                                 NaN
# 20   Real Talk: Fostering diversity and inclusion t...
# 21                                                 NaN
# 22                            Corporate Responsibility
# 23                            Corporate Responsibility
# 24                            Corporate Responsibility
# 25                                      Who We Support
# 26                                      Who We Support
# 27                                      Who We Support
# 28               Autodesk FY2018 Sustainability Report
# 29               Autodesk FY2018 Sustainability Report
# ..                                                 ...
# 279          Western Digital: Global Giving Guidelines
# 280          Western Digital: Global Giving Guidelines
# 281          Western Digital: Global Giving Guidelines
# 282          Western Digital: Global Giving Guidelines
# 283          Western Digital: Global Giving Guidelines
# 284          Western Digital: Global Giving Guidelines
# 285          Western Digital: Global Giving Guidelines
# 286  Western Digital: UK Modern Slavery / Californi...
# 287  Western Digital: UK Modern Slavery / Californi...
# 288  Western Digital: UK Modern Slavery / Californi...
# 289  Western Digital: UK Modern Slavery / Californi...
# 290     Western Digital: U.S. Public Policy Activities
# 291          Western Digital: Responsible Supply Chain
# 292          Western Digital: Responsible Supply Chain
# 293  Western Digital: Membership in Responsible Bus...
# 294  Western Digital: Protecting and Preserving our...
# 295  Western Digital: Protecting and Preserving our...
# 296                                                NA
# 297  itnews: Benchmark Awards 2019 Finalists: Proje...
# 298  GlobeNewswire: Zoom Is a Glassdoor Employees’ ...
# 299  GlobeNewswire: Zoom Donates Video Communicatio...
# 300  Forbes: California Community Colleges Boost Ac...
# 301  Thrive Global: Tips From the Top: One on One w...
# 302  Thrive Global: Tips From the Top: One on One w...
# 303  zoomBlog: Project ECHO and Zoom: Celebrating F...
# 304  Video Conferencing Daily: Video Conferencing B...
# 305  Telecom Reseller: Zoom Video Communications An...
# 306  zoomBlog: Case Study: Zoom & SRA Breaking the ...
# 307  zoomBlog: Case Study: Zoom & SRA Breaking the ...
# 308                                Twitter: @ericsyuan
#
#                                                 Source          Source Type  \
# 0    https://www.adobe.com/content/dam/acom/en/corp...                  PDF
# 1    https://www.adobe.com/content/dam/acom/en/corp...                  PDF
# 2    https://www.adobe.com/content/dam/acom/en/corp...                  PDF
# 3    https://www.adobe.com/content/dam/acom/en/corp...                  PDF
# 4    https://www.adobe.com/content/dam/acom/en/corp...                  PDF
# 5    https://www.adp.com/about-adp/corporate-social...                  PDF
# 6    https://www.adp.com/about-adp/corporate-social...                  PDF
# 7    https://www.adp.com/about-adp/corporate-social...                  PDF
# 8    https://www.adp.com/about-adp/corporate-social...                  PDF
# 9    https://www.adp.com/about-adp/corporate-social...                  PDF
# 10   https://www.adp.com/about-adp/corporate-social...                  PDF
# 11   https://www.adp.com/about-adp/corporate-social...                  PDF
# 12   https://www.adp.com/about-adp/corporate-social...                  PDF
# 13                                                 NaN                  NaN
# 14               https://www.altum.com/community-page/              Webpage
# 15    https://aws.amazon.com/about-aws/sustainability/              Webpage
# 16    https://aws.amazon.com/about-aws/sustainability/              Webpage
# 17    https://aws.amazon.com/about-aws/sustainability/              Webpage
# 18    https://aws.amazon.com/about-aws/sustainability/              Webpage
# 19                                                 NaN                  NaN
# 20   https://blog.asana.com/2018/11/real-talk-event...                 Blog
# 21                                                 NaN                  NaN
# 22   https://www.autodesk.com/sustainability/busine...              Webpage
# 23   https://www.autodesk.com/sustainability/busine...              Webpage
# 24   https://www.autodesk.com/sustainability/busine...              Webpage
# 25   http://www.autodesk.org/who-we-support/stories...              Webpage
# 26   http://www.autodesk.org/who-we-support/stories...              Webpage
# 27   http://www.autodesk.org/who-we-support/stories...              Webpage
# 28   https://damassets.autodesk.net/content/dam/aut...                  PDF
# 29   https://damassets.autodesk.net/content/dam/aut...                  PDF
# ..                                                 ...                  ...
# 279  https://www.westerndigital.com/company/corpora...              Webpage
# 280  https://www.westerndigital.com/company/corpora...              Webpage
# 281  https://www.westerndigital.com/company/corpora...              Webpage
# 282  https://www.westerndigital.com/company/corpora...              Webpage
# 283  https://www.westerndigital.com/company/corpora...              Webpage
# 284  https://www.westerndigital.com/company/corpora...              Webpage
# 285  https://www.westerndigital.com/company/corpora...              Webpage
# 286  https://www.westerndigital.com/company/corpora...              Webpage
# 287  https://www.westerndigital.com/company/corpora...              Webpage
# 288  https://www.westerndigital.com/company/corpora...              Webpage
# 289  https://www.westerndigital.com/company/corpora...              Webpage
# 290  https://www.westerndigital.com/company/corpora...              Webpage
# 291  https://www.westerndigital.com/company/corpora...              Webpage
# 292  https://www.westerndigital.com/company/corpora...              Webpage
# 293  https://www.westerndigital.com/company/corpora...              Webpage
# 294  https://www.westerndigital.com/company/corpora...              Webpage
# 295  https://www.westerndigital.com/company/corpora...              Webpage
# 296                                                NaN                  NaN
# 297  https://www.itnews.com.au/news/benchmark-award...       Online Article
# 298  http://www.globenewswire.com/news-release/2018...       Online Article
# 299  http://www.globenewswire.com/news-release/2018...       Online Article
# 300  https://www.forbes.com/sites/dereknewton/2018/...       Online Article
# 301  https://thriveglobal.com/stories/tips-from-the...       Online Article
# 302  https://thriveglobal.com/stories/tips-from-the...       Online Article
# 303  https://blog.zoom.us/wordpress/2018/07/31/proj...  Self Published Blog
# 304  https://www.videoconferencingdaily.com/educati...       Online Article
# 305  https://telecomreseller.com/2018/01/23/zoom-vi...       Online Article
# 306  https://blog.zoom.us/wordpress/2017/09/05/case...  Self Published Blog
# 307  https://blog.zoom.us/wordpress/2017/09/05/case...  Self Published Blog
# 308  https://twitter.com/ericsyuan/status/769312461...                Tweet
#
#     Source Date             Source Author Explicit or Implicit  \
# 0      8/1/2018                       NaN             Explicit
# 1      8/1/2018                       NaN             Explicit
# 2      8/1/2018                       NaN             Explicit
# 3      8/1/2018                       NaN             Explicit
# 4      8/1/2018                       NaN             Explicit
# 5      2/1/2018                       NaN             Implicit
# 6      2/1/2018                       NaN             Implicit
# 7      2/1/2018                       NaN             Implicit
# 8      2/1/2018                       NaN             Implicit
# 9      2/1/2018                       NaN             Implicit
# 10     2/1/2018                       NaN             Implicit
# 11     2/1/2018                       NaN             Implicit
# 12     2/1/2018                       NaN             Implicit
# 13          NaN                       NaN                  NaN
# 14          NaN                       NaN             Implicit
# 15          NaN                       NaN             Implicit
# 16          NaN                       NaN             Implicit
# 17          NaN                       NaN             Implicit
# 18          NaN                       NaN             Implicit
# 19          NaN                       NaN                  NaN
# 20    11/9/2018                Allie Joel             Implicit
# 21          NaN                       NaN                  NaN
# 22          NaN                       NaN             Implicit
# 23          NaN                       NaN             Implicit
# 24          NaN                       NaN             Implicit
# 25          NaN                       NaN             Implicit
# 26          NaN                       NaN             Implicit
# 27          NaN                       NaN             Implicit
# 28         2018                       NaN             Explicit
# 29         2018                       NaN             Explicit
# ..          ...                       ...                  ...
# 279         NaN                       NaN             Implicit
# 280         NaN                       NaN             Implicit
# 281         NaN                       NaN             Implicit
# 282         NaN                       NaN             Implicit
# 283         NaN                       NaN             Implicit
# 284         NaN                       NaN             Implicit
# 285         NaN                       NaN             Implicit
# 286         NaN  Stephen D. Milligan, CEO             Implicit
# 287         NaN  Stephen D. Milligan, CEO             Implicit
# 288         NaN  Stephen D. Milligan, CEO             Implicit
# 289         NaN  Stephen D. Milligan, CEO             Implicit
# 290         NaN                       NaN             Implicit
# 291         NaN                       NaN             Implicit
# 292         NaN                       NaN             Implicit
# 293         NaN                       NaN             Implicit
# 294         NaN                       NaN             Implicit
# 295         NaN                       NaN             Implicit
# 296         NaN                       NaN                  NaN
# 297   1/13/2019              Matt Johnson             Implicit
# 298   12/4/2018             GlobeNewswire             Implicit
# 299  10/25/2018             GlobeNewswire             Implicit
# 300  12/11/2018              Derek Netwon             Implicit
# 301   6/27/2018              Adam Mendler             Implicit
# 302   6/27/2018              Adam Mendler             Implicit
# 303   7/31/2018                 Zoom Blog             Implicit
# 304    6/4/2018                  Lilian C             Implicit
# 305   1/23/2018          Telecom Reseller             Implicit
# 306    9/5/2017                 Zoom Blog             Implicit
# 307    9/5/2017                 Zoom Blog             Implicit
# 308   8/26/2016        Eric Yuan, Founder             Implicit
#
#                                                  Notes  \
# 0    Adobe is a powerhouse for SDGs. but not for 3 ...
# 1    Adobe is a powerhouse for SDGs. but not for 3 ...
# 2    Adobe is a powerhouse for SDGs. but not for 3 ...
# 3    Adobe is a powerhouse for SDGs. but not for 3 ...
# 4    Adobe is a powerhouse for SDGs. but not for 3 ...
# 5    Very passionate about environmental sustainabi...
# 6    Very passionate about environmental sustainabi...
# 7    Very passionate about environmental sustainabi...
# 8    Very passionate about environmental sustainabi...
# 9    Very passionate about environmental sustainabi...
# 10   Very passionate about environmental sustainabi...
# 11   Very passionate about environmental sustainabi...
# 12   Very passionate about environmental sustainabi...
# 13   I spent too long trying to look for corporate ...
# 14   They are foucsed more on their local community...
# 15   AWS is very into enviornmental sustainability ...
# 16   AWS is very into enviornmental sustainability ...
# 17   AWS is very into enviornmental sustainability ...
# 18   AWS is very into enviornmental sustainability ...
# 19   The company is small and provides non-profits ...
# 20   It's still a start-up, so  don't think they ha...
# 21        Seems to be a very local , domestic company.
# 22   A webpage highlighting AutoDesk's commitment t...
# 23   A webpage highlighting AutoDesk's commitment t...
# 24   A webpage highlighting AutoDesk's commitment t...
# 25   A webpage highlighting the company's major phi...
# 26   A webpage highlighting the company's major phi...
# 27   A webpage highlighting the company's major phi...
# 28   This source is a goldmine and shows explicit s...
# 29   This source is a goldmine and shows explicit s...
# ..                                                 ...
# 279  "The quality of life and education, the well-b...
# 280  "The quality of life and education, the well-b...
# 281  "The quality of life and education, the well-b...
# 282  "The quality of life and education, the well-b...
# 283  "The quality of life and education, the well-b...
# 284  "The quality of life and education, the well-b...
# 285  "The quality of life and education, the well-b...
# 286  "Western Digital is committed to ensuring that...
# 287  "Western Digital is committed to ensuring that...
# 288  "Western Digital is committed to ensuring that...
# 289  "Western Digital is committed to ensuring that...
# 290  "the company does not have or support a politi...
# 291  "We have established and maintain a responsibl...
# 292  "We have established and maintain a responsibl...
# 293  "Western Digital actively participates in the ...
# 294  "At Western Digital, we recognize the need to ...
# 295  "At Western Digital, we recognize the need to ...
# 296  Diffiult to find any information about company...
# 297  Zoom and Project ECHO help diagnose Hep C; Lin...
# 298  "There is no better compliment for Zoom than o...
# 299  Zoom donated tech to University in Israel that...
# 300  California Community College System uses Zoom;...
# 301  "The Zoom book club reimburses employees and t...
# 302  "The Zoom book club reimburses employees and t...
# 303  “Zoom is proud to be a part of this important ...
# 304  "The vendor has donated its services to the st...
# 305  "partnership with a global telehealth integrat...
# 306  "We are proud to help Students Rising Above in...
# 307  "We are proud to help Students Rising Above in...
# 308             Zoom "celebrates" Women's Equality Day
#
#                                       Relevant Country
# 0                                                 U.S.
# 1                                                 U.S.
# 2                                                 U.S.
# 3                                                 U.S.
# 4                                                 U.S.
# 5    Zambia, Uganda, Swaziland, Belize, El Salvador...
# 6    Zambia, Uganda, Swaziland, Belize, El Salvador...
# 7    Zambia, Uganda, Swaziland, Belize, El Salvador...
# 8    Zambia, Uganda, Swaziland, Belize, El Salvador...
# 9    Zambia, Uganda, Swaziland, Belize, El Salvador...
# 10   Zambia, Uganda, Swaziland, Belize, El Salvador...
# 11   Zambia, Uganda, Swaziland, Belize, El Salvador...
# 12   Zambia, Uganda, Swaziland, Belize, El Salvador...
# 13                                                 NaN
# 14                                                U.S.
# 15                                                U.S.
# 16                                                U.S.
# 17                                                U.S.
# 18                                                U.S.
# 19                                                 NaN
# 20                                                U.S.
# 21                                                 NaN
# 22                                                U.S.
# 23                                                U.S.
# 24                                                U.S.
# 25           Honduras, Bolivia, India; Malawai, Zambia
# 26           Honduras, Bolivia, India; Malawai, Zambia
# 27           Honduras, Bolivia, India; Malawai, Zambia
# 28                                                U.S.
# 29                                                U.S.
# ..                                                 ...
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
# 290                                      United States
# 291                                 United States, DRC
# 292                                 United States, DRC
# 293                                      United States
# 294                                      United States
# 295                                      United States
# 296                                                NaN
# 297                                          Australia
# 298                                      United States
# 299                       Israel, United States, China
# 300                                      United States
# 301                                                NaN
# 302                                                NaN
# 303                                      United States
# 304                                      United States
# 305                                                NaN
# 306                                      United States
# 307                                      United States
# 308                                      United States
#
# [309 rows x 10 columns]

# %%
#Making the country NaNs string "nan"s in order to pass through repRow
cleanTest.iloc[:, 9] = cleanTest.iloc[:, 9].fillna("nan")
np.unique(cleanTest.iloc[:, 9])
# Out:
# array(['Australia', 'Chile, Haiti, Japan, Pakistan, United States',
#        'China, India, Israel, Japan, Malaysia, Philippines, Thailand, United States',
#        'Germany, USA', 'Global',
#        'Global, United States, United Kingdom, France, Australia, China, Hong Kong, Japan, Singapore, Netherlands, Germany, Sweden',
#        'Globe', 'Globe, UK, United States',
#        'Haiti, India, Mozambique, Peru, Sri Lanka, Tanzania',
#        'Honduras, Bolivia, India; Malawai, Zambia', 'India',
#        'Israel, United States, China', 'Lebanon', 'Local', 'Mexico',
#        'Nigeria, Uganda, DRC, Afghanistan', 'Rwanda', 'South Africa',
#        'U.S.', 'U.S., the United Kingdom', 'United States',
#        'United States (local)',
#        'United States, Africa, Central Asia, Middle East',
#        'United States, Australia, India, Guatemala, Kenya, Madagascar, Borneo, Brazil,\nZimbabwe, and Sierra Leone',
#        'United States, DRC', 'United States, Globe',
#        'United States, Haiti', 'United States, North Korea',
#        'Zambia, Uganda, Swaziland, Belize, El Salvador, Haiti, U.S., Chile, India, Romania\nand the Philippines',
#        'nan'], dtype=object)

# %%
################################
## Cleanup of Country wording ##
################################

#Getting rid of newline characters
cleanTest.iloc[:, 9] = [re.sub('\\n', "", row) for row in cleanTest.iloc[:, 9]]

#Getting rid of the word "and"
cleanTest.iloc[:, 9] = [re.sub(' and ', "", row) for row in cleanTest.iloc[:, 9]]

#Getting rid of the word "the"
cleanTest.iloc[:, 9] = [re.sub(' the ', ",", row) for row in cleanTest.iloc[:, 9]]

#Changing all "U.S." to "United States"
cleanTest.iloc[:, 9] = [re.sub(' *U.?S.? *', "United States", row) for row in cleanTest.iloc[:, 9]] 

#Changing all "UK" to "United Kingdom"
cleanTest.iloc[:, 9] = [re.sub(' *U.?K.? *', "United States", row) for row in cleanTest.iloc[:, 9]] 

#Changing all "Globe" to "Global"
cleanTest.iloc[:, 9] = [re.sub(' *[Gg]lobe *', "Global", row) for row in cleanTest.iloc[:, 9]]


np.unique(cleanTest.iloc[:, 9])
# Out:
# array(['Australia', 'Chile, Haiti, Japan, Pakistan, United States',
#        'China, India, Israel, Japan, Malaysia, Philippines, Thailand, United States',
#        'Germany,United States', 'Global',
#        'Global, United States, United Kingdom, France, Australia, China, Hong Kong, Japan, Singapore, Netherlands, Germany, Sweden',
#        'Global,United StatesUnited States',
#        'Haiti, India, Mozambique, Peru, Sri Lanka, Tanzania',
#        'Honduras, Bolivia, India; Malawai, Zambia', 'India',
#        'Israel, United States, China', 'Lebanon', 'Local', 'Mexico',
#        'Nigeria, Uganda, DRC, Afghanistan', 'Rwanda', 'South Africa',
#        'United States', 'United States (local)',
#        'United States, Africa, Central Asia, Middle East',
#        'United States, Australia, India, Guatemala, Kenya, Madagascar, Borneo, Brazil,Zimbabwe,Sierra Leone',
#        'United States, DRC', 'United States, Haiti',
#        'United States, North Korea', 'United States,,United Kingdom',
#        'United States,Global',
#        'Zambia, Uganda, Swaziland, Belize, El Salvador, Haiti,United States, Chile, India, Romaniaand,Philippines',
#        'nan'], dtype=object)

# %%
len(cleanTest.iloc[:, 0])
# Out:
# 309

# %%
cleanCountry = pd.DataFrame([])
for row in range(len(cleanTest.iloc[:, 0])):
    cleanCountry = cleanCountry.append(repRow(cleanTest.iloc[row, :], 9, 
                                        splitStr), 
                                 ignore_index = True)
cleanCountry
# Out:
#          Corporation SDG(s)   \
# 0              Adobe       4
# 1              Adobe       5
# 2              Adobe       8
# 3              Adobe      12
# 4              Adobe      13
# 5                ADP       1
# 6                ADP       1
# 7                ADP       1
# 8                ADP       1
# 9                ADP       1
# 10               ADP       1
# 11               ADP       1
# 12               ADP       1
# 13               ADP       1
# 14               ADP       1
# 15               ADP       1
# 16               ADP       2
# 17               ADP       2
# 18               ADP       2
# 19               ADP       2
# 20               ADP       2
# 21               ADP       2
# 22               ADP       2
# 23               ADP       2
# 24               ADP       2
# 25               ADP       2
# 26               ADP       2
# 27               ADP       3
# 28               ADP       3
# 29               ADP       3
# ..               ...     ...
# 513  Western Digital      11
# 514  Western Digital      13
# 515  Western Digital      16
# 516  Western Digital       3
# 517  Western Digital       8
# 518  Western Digital      12
# 519  Western Digital      16
# 520  Western Digital      16
# 521  Western Digital      12
# 522  Western Digital      12
# 523  Western Digital      17
# 524  Western Digital      17
# 525  Western Digital      17
# 526  Western Digital      12
# 527  Western Digital      13
# 528            Zoner       0
# 529             Zoom       3
# 530             Zoom       8
# 531             Zoom       4
# 532             Zoom       4
# 533             Zoom       4
# 534             Zoom       4
# 535             Zoom       4
# 536             Zoom       8
# 537             Zoom       3
# 538             Zoom       4
# 539             Zoom      11
# 540             Zoom       1
# 541             Zoom       4
# 542             Zoom       5
#
#                                            Source Name  \
# 0    Adobe Alignment to UN Sustainable Development ...
# 1    Adobe Alignment to UN Sustainable Development ...
# 2    Adobe Alignment to UN Sustainable Development ...
# 3    Adobe Alignment to UN Sustainable Development ...
# 4    Adobe Alignment to UN Sustainable Development ...
# 5               Corporate Social Responsibility Report
# 6               Corporate Social Responsibility Report
# 7               Corporate Social Responsibility Report
# 8               Corporate Social Responsibility Report
# 9               Corporate Social Responsibility Report
# 10              Corporate Social Responsibility Report
# 11              Corporate Social Responsibility Report
# 12              Corporate Social Responsibility Report
# 13              Corporate Social Responsibility Report
# 14              Corporate Social Responsibility Report
# 15              Corporate Social Responsibility Report
# 16              Corporate Social Responsibility Report
# 17              Corporate Social Responsibility Report
# 18              Corporate Social Responsibility Report
# 19              Corporate Social Responsibility Report
# 20              Corporate Social Responsibility Report
# 21              Corporate Social Responsibility Report
# 22              Corporate Social Responsibility Report
# 23              Corporate Social Responsibility Report
# 24              Corporate Social Responsibility Report
# 25              Corporate Social Responsibility Report
# 26              Corporate Social Responsibility Report
# 27              Corporate Social Responsibility Report
# 28              Corporate Social Responsibility Report
# 29              Corporate Social Responsibility Report
# ..                                                 ...
# 513          Western Digital: Global Giving Guidelines
# 514          Western Digital: Global Giving Guidelines
# 515          Western Digital: Global Giving Guidelines
# 516  Western Digital: UK Modern Slavery / Californi...
# 517  Western Digital: UK Modern Slavery / Californi...
# 518  Western Digital: UK Modern Slavery / Californi...
# 519  Western Digital: UK Modern Slavery / Californi...
# 520     Western Digital: U.S. Public Policy Activities
# 521          Western Digital: Responsible Supply Chain
# 522          Western Digital: Responsible Supply Chain
# 523          Western Digital: Responsible Supply Chain
# 524          Western Digital: Responsible Supply Chain
# 525  Western Digital: Membership in Responsible Bus...
# 526  Western Digital: Protecting and Preserving our...
# 527  Western Digital: Protecting and Preserving our...
# 528                                                NA
# 529  itnews: Benchmark Awards 2019 Finalists: Proje...
# 530  GlobeNewswire: Zoom Is a Glassdoor Employees’ ...
# 531  GlobeNewswire: Zoom Donates Video Communicatio...
# 532  GlobeNewswire: Zoom Donates Video Communicatio...
# 533  GlobeNewswire: Zoom Donates Video Communicatio...
# 534  Forbes: California Community Colleges Boost Ac...
# 535  Thrive Global: Tips From the Top: One on One w...
# 536  Thrive Global: Tips From the Top: One on One w...
# 537  zoomBlog: Project ECHO and Zoom: Celebrating F...
# 538  Video Conferencing Daily: Video Conferencing B...
# 539  Telecom Reseller: Zoom Video Communications An...
# 540  zoomBlog: Case Study: Zoom & SRA Breaking the ...
# 541  zoomBlog: Case Study: Zoom & SRA Breaking the ...
# 542                                Twitter: @ericsyuan
#
#                                                 Source          Source Type  \
# 0    https://www.adobe.com/content/dam/acom/en/corp...                  PDF
# 1    https://www.adobe.com/content/dam/acom/en/corp...                  PDF
# 2    https://www.adobe.com/content/dam/acom/en/corp...                  PDF
# 3    https://www.adobe.com/content/dam/acom/en/corp...                  PDF
# 4    https://www.adobe.com/content/dam/acom/en/corp...                  PDF
# 5    https://www.adp.com/about-adp/corporate-social...                  PDF
# 6    https://www.adp.com/about-adp/corporate-social...                  PDF
# 7    https://www.adp.com/about-adp/corporate-social...                  PDF
# 8    https://www.adp.com/about-adp/corporate-social...                  PDF
# 9    https://www.adp.com/about-adp/corporate-social...                  PDF
# 10   https://www.adp.com/about-adp/corporate-social...                  PDF
# 11   https://www.adp.com/about-adp/corporate-social...                  PDF
# 12   https://www.adp.com/about-adp/corporate-social...                  PDF
# 13   https://www.adp.com/about-adp/corporate-social...                  PDF
# 14   https://www.adp.com/about-adp/corporate-social...                  PDF
# 15   https://www.adp.com/about-adp/corporate-social...                  PDF
# 16   https://www.adp.com/about-adp/corporate-social...                  PDF
# 17   https://www.adp.com/about-adp/corporate-social...                  PDF
# 18   https://www.adp.com/about-adp/corporate-social...                  PDF
# 19   https://www.adp.com/about-adp/corporate-social...                  PDF
# 20   https://www.adp.com/about-adp/corporate-social...                  PDF
# 21   https://www.adp.com/about-adp/corporate-social...                  PDF
# 22   https://www.adp.com/about-adp/corporate-social...                  PDF
# 23   https://www.adp.com/about-adp/corporate-social...                  PDF
# 24   https://www.adp.com/about-adp/corporate-social...                  PDF
# 25   https://www.adp.com/about-adp/corporate-social...                  PDF
# 26   https://www.adp.com/about-adp/corporate-social...                  PDF
# 27   https://www.adp.com/about-adp/corporate-social...                  PDF
# 28   https://www.adp.com/about-adp/corporate-social...                  PDF
# 29   https://www.adp.com/about-adp/corporate-social...                  PDF
# ..                                                 ...                  ...
# 513  https://www.westerndigital.com/company/corpora...              Webpage
# 514  https://www.westerndigital.com/company/corpora...              Webpage
# 515  https://www.westerndigital.com/company/corpora...              Webpage
# 516  https://www.westerndigital.com/company/corpora...              Webpage
# 517  https://www.westerndigital.com/company/corpora...              Webpage
# 518  https://www.westerndigital.com/company/corpora...              Webpage
# 519  https://www.westerndigital.com/company/corpora...              Webpage
# 520  https://www.westerndigital.com/company/corpora...              Webpage
# 521  https://www.westerndigital.com/company/corpora...              Webpage
# 522  https://www.westerndigital.com/company/corpora...              Webpage
# 523  https://www.westerndigital.com/company/corpora...              Webpage
# 524  https://www.westerndigital.com/company/corpora...              Webpage
# 525  https://www.westerndigital.com/company/corpora...              Webpage
# 526  https://www.westerndigital.com/company/corpora...              Webpage
# 527  https://www.westerndigital.com/company/corpora...              Webpage
# 528                                                NaN                  NaN
# 529  https://www.itnews.com.au/news/benchmark-award...       Online Article
# 530  http://www.globenewswire.com/news-release/2018...       Online Article
# 531  http://www.globenewswire.com/news-release/2018...       Online Article
# 532  http://www.globenewswire.com/news-release/2018...       Online Article
# 533  http://www.globenewswire.com/news-release/2018...       Online Article
# 534  https://www.forbes.com/sites/dereknewton/2018/...       Online Article
# 535  https://thriveglobal.com/stories/tips-from-the...       Online Article
# 536  https://thriveglobal.com/stories/tips-from-the...       Online Article
# 537  https://blog.zoom.us/wordpress/2018/07/31/proj...  Self Published Blog
# 538  https://www.videoconferencingdaily.com/educati...       Online Article
# 539  https://telecomreseller.com/2018/01/23/zoom-vi...       Online Article
# 540  https://blog.zoom.us/wordpress/2017/09/05/case...  Self Published Blog
# 541  https://blog.zoom.us/wordpress/2017/09/05/case...  Self Published Blog
# 542  https://twitter.com/ericsyuan/status/769312461...                Tweet
#
#     Source Date             Source Author Explicit or Implicit  \
# 0      8/1/2018                       NaN             Explicit
# 1      8/1/2018                       NaN             Explicit
# 2      8/1/2018                       NaN             Explicit
# 3      8/1/2018                       NaN             Explicit
# 4      8/1/2018                       NaN             Explicit
# 5      2/1/2018                       NaN             Implicit
# 6      2/1/2018                       NaN             Implicit
# 7      2/1/2018                       NaN             Implicit
# 8      2/1/2018                       NaN             Implicit
# 9      2/1/2018                       NaN             Implicit
# 10     2/1/2018                       NaN             Implicit
# 11     2/1/2018                       NaN             Implicit
# 12     2/1/2018                       NaN             Implicit
# 13     2/1/2018                       NaN             Implicit
# 14     2/1/2018                       NaN             Implicit
# 15     2/1/2018                       NaN             Implicit
# 16     2/1/2018                       NaN             Implicit
# 17     2/1/2018                       NaN             Implicit
# 18     2/1/2018                       NaN             Implicit
# 19     2/1/2018                       NaN             Implicit
# 20     2/1/2018                       NaN             Implicit
# 21     2/1/2018                       NaN             Implicit
# 22     2/1/2018                       NaN             Implicit
# 23     2/1/2018                       NaN             Implicit
# 24     2/1/2018                       NaN             Implicit
# 25     2/1/2018                       NaN             Implicit
# 26     2/1/2018                       NaN             Implicit
# 27     2/1/2018                       NaN             Implicit
# 28     2/1/2018                       NaN             Implicit
# 29     2/1/2018                       NaN             Implicit
# ..          ...                       ...                  ...
# 513         NaN                       NaN             Implicit
# 514         NaN                       NaN             Implicit
# 515         NaN                       NaN             Implicit
# 516         NaN  Stephen D. Milligan, CEO             Implicit
# 517         NaN  Stephen D. Milligan, CEO             Implicit
# 518         NaN  Stephen D. Milligan, CEO             Implicit
# 519         NaN  Stephen D. Milligan, CEO             Implicit
# 520         NaN                       NaN             Implicit
# 521         NaN                       NaN             Implicit
# 522         NaN                       NaN             Implicit
# 523         NaN                       NaN             Implicit
# 524         NaN                       NaN             Implicit
# 525         NaN                       NaN             Implicit
# 526         NaN                       NaN             Implicit
# 527         NaN                       NaN             Implicit
# 528         NaN                       NaN                  NaN
# 529   1/13/2019              Matt Johnson             Implicit
# 530   12/4/2018             GlobeNewswire             Implicit
# 531  10/25/2018             GlobeNewswire             Implicit
# 532  10/25/2018             GlobeNewswire             Implicit
# 533  10/25/2018             GlobeNewswire             Implicit
# 534  12/11/2018              Derek Netwon             Implicit
# 535   6/27/2018              Adam Mendler             Implicit
# 536   6/27/2018              Adam Mendler             Implicit
# 537   7/31/2018                 Zoom Blog             Implicit
# 538    6/4/2018                  Lilian C             Implicit
# 539   1/23/2018          Telecom Reseller             Implicit
# 540    9/5/2017                 Zoom Blog             Implicit
# 541    9/5/2017                 Zoom Blog             Implicit
# 542   8/26/2016        Eric Yuan, Founder             Implicit
#
#                                                  Notes Relevant Country
# 0    Adobe is a powerhouse for SDGs. but not for 3 ...    United States
# 1    Adobe is a powerhouse for SDGs. but not for 3 ...    United States
# 2    Adobe is a powerhouse for SDGs. but not for 3 ...    United States
# 3    Adobe is a powerhouse for SDGs. but not for 3 ...    United States
# 4    Adobe is a powerhouse for SDGs. but not for 3 ...    United States
# 5    Very passionate about environmental sustainabi...           Zambia
# 6    Very passionate about environmental sustainabi...           Uganda
# 7    Very passionate about environmental sustainabi...        Swaziland
# 8    Very passionate about environmental sustainabi...           Belize
# 9    Very passionate about environmental sustainabi...      El Salvador
# 10   Very passionate about environmental sustainabi...            Haiti
# 11   Very passionate about environmental sustainabi...    United States
# 12   Very passionate about environmental sustainabi...            Chile
# 13   Very passionate about environmental sustainabi...            India
# 14   Very passionate about environmental sustainabi...       Romaniaand
# 15   Very passionate about environmental sustainabi...      Philippines
# 16   Very passionate about environmental sustainabi...           Zambia
# 17   Very passionate about environmental sustainabi...           Uganda
# 18   Very passionate about environmental sustainabi...        Swaziland
# 19   Very passionate about environmental sustainabi...           Belize
# 20   Very passionate about environmental sustainabi...      El Salvador
# 21   Very passionate about environmental sustainabi...            Haiti
# 22   Very passionate about environmental sustainabi...    United States
# 23   Very passionate about environmental sustainabi...            Chile
# 24   Very passionate about environmental sustainabi...            India
# 25   Very passionate about environmental sustainabi...       Romaniaand
# 26   Very passionate about environmental sustainabi...      Philippines
# 27   Very passionate about environmental sustainabi...           Zambia
# 28   Very passionate about environmental sustainabi...           Uganda
# 29   Very passionate about environmental sustainabi...        Swaziland
# ..                                                 ...              ...
# 513  "The quality of life and education, the well-b...              nan
# 514  "The quality of life and education, the well-b...              nan
# 515  "The quality of life and education, the well-b...              nan
# 516  "Western Digital is committed to ensuring that...              nan
# 517  "Western Digital is committed to ensuring that...              nan
# 518  "Western Digital is committed to ensuring that...              nan
# 519  "Western Digital is committed to ensuring that...              nan
# 520  "the company does not have or support a politi...    United States
# 521  "We have established and maintain a responsibl...    United States
# 522  "We have established and maintain a responsibl...              DRC
# 523  "We have established and maintain a responsibl...    United States
# 524  "We have established and maintain a responsibl...              DRC
# 525  "Western Digital actively participates in the ...    United States
# 526  "At Western Digital, we recognize the need to ...    United States
# 527  "At Western Digital, we recognize the need to ...    United States
# 528  Diffiult to find any information about company...              nan
# 529  Zoom and Project ECHO help diagnose Hep C; Lin...        Australia
# 530  "There is no better compliment for Zoom than o...    United States
# 531  Zoom donated tech to University in Israel that...           Israel
# 532  Zoom donated tech to University in Israel that...    United States
# 533  Zoom donated tech to University in Israel that...            China
# 534  California Community College System uses Zoom;...    United States
# 535  "The Zoom book club reimburses employees and t...              nan
# 536  "The Zoom book club reimburses employees and t...              nan
# 537  “Zoom is proud to be a part of this important ...    United States
# 538  "The vendor has donated its services to the st...    United States
# 539  "partnership with a global telehealth integrat...              nan
# 540  "We are proud to help Students Rising Above in...    United States
# 541  "We are proud to help Students Rising Above in...    United States
# 542             Zoom "celebrates" Women's Equality Day    United States
#
# [543 rows x 10 columns]

# %%
#Could not get rid of a space: doing it manually"
cleanCountry = cleanCountry[cleanCountry['Relevant Country'] != ""]

# %%
cleanCountry.to_csv("2019.02.21_Cleaned_Corporate_Donor_Sheet.csv")
