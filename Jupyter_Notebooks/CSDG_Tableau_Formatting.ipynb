# %%
import numpy as np
import pandas as pd
import re

# %%
csdg = pd.read_csv("2019.02.20_Cleaned_Corporate_Donor_Sheet.csv")
csdg = csdg.iloc[:, 1:11]

# %%
csdg#.groupby('Relevant Country').agg(list)
# Out:
#                    Corporation  SDG(s)   \
# 0                        Adobe        4
# 1                        Adobe        5
# 2                        Adobe        8
# 3                        Adobe       12
# 4                        Adobe       13
# 5                          ADP        1
# 6                          ADP        1
# 7                          ADP        1
# 8                          ADP        1
# 9                          ADP        1
# 10                         ADP        1
# 11                         ADP        1
# 12                         ADP        1
# 13                         ADP        1
# 14                         ADP        1
# 15                         ADP        1
# 16                         ADP        2
# 17                         ADP        2
# 18                         ADP        2
# 19                         ADP        2
# 20                         ADP        2
# 21                         ADP        2
# ...
